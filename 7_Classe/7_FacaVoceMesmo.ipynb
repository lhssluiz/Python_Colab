# %%
#9.10 Calling restauranr

import sys
sys.path.append ('/content/drive/MyDrive/Colab_Notebooks/7_Classe')

# %%
from restaurant_module import Restaurant

test = Restaurant('Camarões','Frutos do Mar')

test.describe_restaurant()
# Out:
# The restarant Camarões has this cuisine type Frutos do Mar.

# %%
import user
import admin_privileges

# %%
user_admin = admin_privileges.Admin('Luiz','Sá',3434,0)
# Learning:
# I wasn't using dot notation. In this case that I imported
# All the module and not a specific class
# I need to use the dot notation
user_admin.privileges_admin.show_privileges()
# Out:
# These are all your rights:
# can add post
# can delete post
# can be user
